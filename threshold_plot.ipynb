# %%
import numpy as np
from matplotlib import pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
best_threshold = 8
f1_mean = 0.8080995478780543
d = {
    'esp5': [0.7632759107596724, 0.7673986747886273, 0.7832898172323759, 0.7745537602571695, 0.77712328468268, 0.7633925281851006, 0.7611296513698539, 0.754941211176198, 0.7637268806622477, 0.7262709742048584, 0.703348767093787], 
    'esp6': [0.806219123256832, 0.8322919270182454, 0.8274362522237596, 0.7957450104567402, 0.7846071300822702, 0.7561255343551248, 0.7252086811352254, 0.7119794649865291, 0.700701949355318, 0.6849567978731261, 0.6752825853068922], 
    'esp2': [0.7516057800333166, 0.7908282639213852, 0.8135725741780273, 0.8430599011472363, 0.8563780600574292, 0.8663971754592437, 0.8742310703500727, 0.8800961055945012, 0.88449700307792, 0.8674630362626244, 0.8468631066818378]
}

esp5_f1 = d['esp5']
esp6_f1 = d['esp6']
esp2_f1 = d['esp2']

# %%
# plot the varying values of the IQR multiplier against F-measure for various tracks
fig = plt.figure(figsize=(13,7))
x_iqr = np.arange(6,17,1)
plt.plot(x_iqr,esp2_f1, label='esp2')
plt.plot(x_iqr,esp5_f1, label='esp5')
plt.plot(x_iqr,esp6_f1, label='esp6')
plt.legend(loc = "upper right")
plt.title('F-measure vs. Threshold IQR Multiplier')
plt.xlabel('IQR Multiplier')
plt.ylabel('F-measure')
plt.ylim([0.65,0.9])
# Out:
# (0.65, 0.9)
